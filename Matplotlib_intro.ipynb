# %% [markdown]
# <a href="https://colab.research.google.com/github/darsan-0/Python_lib_for_ML/blob/main/Matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# (X,Y) -->(1,5),(2,6)....

# %%
X = [1,2,3,4]
Y = [5,6,7,8]

# %%
plt.plot(X,Y)
plt.grid()
plt.show()

# %% [markdown]
# **Pyplot API**

# %%
# univarite analaysis --> Numerical.

# %%
data = {
    "Salary":[25000,30000,100000,40000,27000,70000,35000,22000,95000]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Salary
# 0   25000
# 1   30000
# 2  100000
# 3   40000
# 4   27000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  9 non-null      int64
# dtypes: int64(1)
# memory usage: 204.0 bytes

# %% [markdown]
# Line Plot

# %%
plt.plot(df["Salary"],color="red",marker="*",linestyle="-.",linewidth=1)
plt.grid()
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(data["Salary"],bins=2,color="pink") #bins--> Used to devide the graph...into parts.
plt.show()

# %% [markdown]
# Boxplot

# %%
plt.boxplot(data["Salary"]) #bins--> Used to devide the graph...into parts.
plt.show()

# %%
df.drop(index=2,inplace=True)

# %%
df.shape
# Out:
# (8, 1)

# %%
# univarite analaysis --> Categorical.

# %%
df["dept"]=["HR","IT","Finance","IT","IT","IT","HR","IT"]

# %%
df
# Out:
#    Salary     dept
# 0   25000       HR
# 1   30000       IT
# 3   40000  Finance
# 4   27000       IT
# 5   70000       IT
# 6   35000       IT
# 7   22000       HR
# 8   95000       IT

# %%
count = df["dept"].value_counts()
count
# Out:
# dept
# IT         5
# HR         2
# Finance    1
# Name: count, dtype: int64

# %%
plt.pie(count,labels= count.index,autopct="%1.2f",explode=[0.2,0.1,0])
plt.axis("equal")
plt.show()

# %%
#countplot
plt.bar(count.index,count,color=["Green","black","pink"])
plt.show()

# %%
# Bivarite analaysis --> Numerical.

# %%
df["Age"] = [22,36,37,45]*2
df
# Out:
#    Salary     dept  Age
# 0   25000       HR   22
# 1   30000       IT   36
# 3   40000  Finance   37
# 4   27000       IT   45
# 5   70000       IT   22
# 6   35000       IT   36
# 7   22000       HR   37
# 8   95000       IT   45

# %%
#Scatter plot:
plt.scatter(df["Age"],df["Salary"],color="red")

# %%
sort_age = df.sort_values('Age')
sort_sal = df.sort_values('Salary')

# %%
#Line plot
plt.plot(sort_age["Age"],sort_sal["Salary"],color="red",marker="o")
plt.grid()
plt.show()

# %%
# Bar chart
plt.bar(sort_age["Age"],sort_sal["Salary"],color="Green")
# Out:
# <BarContainer object of 8 artists>

# %%
# Bivarite analaysis --> Numerical-categorical

# %%
hr_sal =df[df["dept"] == "HR"]["Salary"]
hr_sal
# Out:
# 0    25000
# 7    22000
# Name: Salary, dtype: int64

# %%
it_sal =df[df["dept"] == "IT"]["Salary"]
it_sal
# Out:
# 1    30000
# 4    27000
# 5    70000
# 6    35000
# 8    95000
# Name: Salary, dtype: int64

# %%
fin_sal =df[df["dept"] == "Finance"]["Salary"]
fin_sal
# Out:
# 3    40000
# Name: Salary, dtype: int64

# %%
plt.boxplot([hr_sal,it_sal,fin_sal],labels=["HR","IT","Finance"])
plt.show()
# Out:
# /tmp/ipython-input-3028507748.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal,it_sal,fin_sal],labels=["HR","IT","Finance"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  8 non-null      int64
#  1   dept    8 non-null      object
#  2   Age     8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 256.0+ bytes

# %%
plt.bar(df['dept'],df['Salary'] ,color='Green')
plt.show()

# %%
sal_by_dept = df.groupby('dept')["Salary"].sum()
sal_by_dept
# Out:
# dept
# Finance     40000
# HR          47000
# IT         257000
# Name: Salary, dtype: int64

# %%
plt.pie(sal_by_dept, labels = sal_by_dept.index, autopct = "%1.2f" , explode=[0.2,0,0])
plt.axis("equal")
plt.show()

# %%
# bar plot
hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(fin_sal)/len(fin_sal)

# %%
plt.bar(["HR", "IT", "Finance"], [hr_mean, it_mean, fin_mean], color = ["green", "black", "red"])
plt.show()

# %%
#Multivariate Analysis: 3 nemeric colums
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   22
# 1   30000       IT   36
# 3   40000  Finance   37
# 4   27000       IT   45
# 5   70000       IT   22

# %%
df['Exp'] = [1,1.5,2,2.5]*2
df
# Out:
#    Salary     dept  Age  Exp
# 0   25000       HR   22  1.0
# 1   30000       IT   36  1.5
# 3   40000  Finance   37  2.0
# 4   27000       IT   45  2.5
# 5   70000       IT   22  1.0
# 6   35000       IT   36  1.5
# 7   22000       HR   37  2.0
# 8   95000       IT   45  2.5

# %%
#Bubble plot
plt.scatter(df['Age'],df['Salary'],s = df['Exp']*20,color = "orange",edgecolor="black")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.grid()
plt.show()

# %%
#2 numerical and 1 categorical column:

# %%
plt.scatter(df['Age'],df['Salary'], c =df['dept'].map({"HR":"Yellow","IT":"red","Finance":"Green"}))
plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-3509863543.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
color = {"HR": "yellow", "IT": "blue", "Finance": "orange"}
for dept, color in color.items():
  df_dept = df[df["dept"] == dept]
  plt.scatter(df_dept["Age"], df_dept["Salary"], c =color, label= dept)
plt.legend()

# %%
#Object oriented API

# %%
fig,axs = plt.subplots(1,3,figsize = (20,5)) #In one fig i want's 3 subplots
#Line plot
axs[0].plot(sort_age["Age"], df["Salary"], color = "red", marker="*",linewidth = "2")
axs[0].grid()
axs[0].set_title("Line Plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")


# histogram:
axs [1].hist(df["Salary"], bins =3, color="Pink")
axs[1].set_title("Histogram")
axs[1].set_xlabel("Salary")
axs[1].set_ylabel("Frequency")

# Boxplot:
axs [2].boxplot(df["Salary"])
axs [2].set_title("Boxplot")
axs [2].set_xlabel("Salary")

#This the statement to save the ploted graph in our local device
plt.savefig("Muntiple_plots.png")

plt.show()

# %%
data2 = {
'Year':
[2020, 2021, 2022, 2023],
'Sales': [
100, 150, 200, 250],
'Profit':
[20, 30, 40, 50],
"Expenses":
[80, 120, 160, 200]
}

df2 = pd.DataFrame (data2)

# %%
df2.head()
# Out:
#    Year  Sales  Profit  Expenses
# 0  2020    100      20        80
# 1  2021    150      30       120
# 2  2022    200      40       160
# 3  2023    250      50       200

# %%
plt.plot(df2["Year"], df2["Sales"], label = "Sales")
plt.plot(df2["Year"], df2["Profit"], label = "Profit")
plt.plot(df2["Year"], df2["Expenses"], label = "Expenses")
plt.title("Financial Analysis")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    Salary     dept  Age  Exp
# 0   25000       HR   22  1.0
# 1   30000       IT   36  1.5
# 3   40000  Finance   37  2.0
# 4   27000       IT   45  2.5
# 5   70000       IT   22  1.0

# %%
ax = plt.axes(projection="3d")

ax.scatter(
    df["Age"],        # X-axis
    df["Salary"],     # Y-axis
    df["Exp"]  # Z-axis
)

ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")

plt.show()

# %%
import plotly.express as px
fig= px.scatter_3d(df, x='Age', y='Salary', z='Exp',title="3D Scatter plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
