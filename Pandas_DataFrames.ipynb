# %% [markdown]
# <a href="https://colab.research.google.com/github/darsan-0/Python_lib_for_ML/blob/main/Pandas_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "name": ["Alice", "Bob", "Charlie", "David", "Eve","Alice"],
    "age": [30, 24, 45, np.nan, 29,30],
    "department": ["HR", "IT", "Finance", "IT", "HR","HR"],
    "salary": [60000, np.nan, 90000, 70000, 62000,60000]
}
df = pd.DataFrame(data)
df
# Out:
#       name   age department   salary
# 0    Alice  30.0         HR  60000.0
# 1      Bob  24.0         IT      NaN
# 2  Charlie  45.0    Finance  90000.0
# 3    David   NaN         IT  70000.0
# 4      Eve  29.0         HR  62000.0
# 5    Alice  30.0         HR  60000.0

# %%
# sawa Starting few rows --->head(Value),Value not manadory defalut - 5.
df.head(3)
# Out:
#       name   age department   salary
# 0    Alice  30.0         HR  60000.0
# 1      Bob  24.0         IT      NaN
# 2  Charlie  45.0    Finance  90000.0

# %%
# sawa Ending few rows --->tail(Value),Value not manadory defalut - 5.
df.tail(2)
# Out:
#     name   age department   salary
# 4    Eve  29.0         HR  62000.0
# 5  Alice  30.0         HR  60000.0

# %%
# loc and iloc
df.iloc[1:3] #row,column
# Out:
#       name   age department   salary
# 1      Bob  24.0         IT      NaN
# 2  Charlie  45.0    Finance  90000.0

# %%
df.loc[1:3,["name","department","age"]]
# Out:
#       name department   age
# 1      Bob         IT  24.0
# 2  Charlie    Finance  45.0
# 3    David         IT   NaN

# %%
#Accesing required column.
df[['age',"salary"]]
# Out:
#     age   salary
# 0  30.0  60000.0
# 1  24.0      NaN
# 2  45.0  90000.0
# 3   NaN  70000.0
# 4  29.0  62000.0
# 5  30.0  60000.0

# %%
df.drop("age",axis=1,inplace=False)# if inplace is True the age column was compltely deleteed.
# axis=1 specifes you wants to delete complte column...if axis=0 then you can choose requied row to drop it...
# Out:
#       name department   salary
# 0    Alice         HR  60000.0
# 1      Bob         IT      NaN
# 2  Charlie    Finance  90000.0
# 3    David         IT  70000.0
# 4      Eve         HR  62000.0
# 5    Alice         HR  60000.0

# %%
df.drop(2, axis=0, inplace=False)
# Out:
#     Name   Age Dept   salary  promoted salary
# 0  Alice  30.0   HR  65000.0         650000.0
# 1    Bob  24.0   IT      NaN              NaN
# 3  David  31.6   IT  75000.0          75000.0
# 4    Eve  29.0   HR  67000.0          67000.0

# %%
df
# Out:
#       name   age department   salary
# 0    Alice  30.0         HR  60000.0
# 1      Bob  24.0         IT      NaN
# 2  Charlie  45.0    Finance  90000.0
# 3    David   NaN         IT  70000.0
# 4      Eve  29.0         HR  62000.0
# 5    Alice  30.0         HR  60000.0

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        6 non-null      object
#  1   age         5 non-null      float64
#  2   department  6 non-null      object
#  3   salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              age        salary
# count   5.000000      5.000000
# mean   31.600000  68400.000000
# std     7.893035  12759.310326
# min    24.000000  60000.000000
# 25%    29.000000  60000.000000
# 50%    30.000000  62000.000000
# 75%    30.000000  70000.000000
# max    45.000000  90000.000000

# %%
#Broadcasting
df['salary']=df['salary']+5000

# %%
df
# Out:
#       name   age department   salary
# 0    Alice  30.0         HR  65000.0
# 1      Bob  24.0         IT      NaN
# 2  Charlie  45.0    Finance  95000.0
# 3    David   NaN         IT  75000.0
# 4      Eve  29.0         HR  67000.0
# 5    Alice  30.0         HR  65000.0

# %%
#Renamimg columns:
df.rename(columns={"department":"Dept","age":"Age","name":"Name"},inplace=True)

# %%
df
# Out:
#       Name   Age     Dept   salary
# 0    Alice  30.0       HR  65000.0
# 1      Bob  24.0       IT      NaN
# 2  Charlie  45.0  Finance  95000.0
# 3    David   NaN       IT  75000.0
# 4      Eve  29.0       HR  67000.0
# 5    Alice  30.0       HR  65000.0

# %%
#To find out unique value in the specified column..
df['Name'].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie', 'David', 'Eve'], dtype=object)

# %%
df["Dept"].value_counts()
# Out:
# Dept
# HR         2
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
#inserting new date into a dataframe
df['promoted salary'] = df['salary'] * 10
df
# Out:
#       Name   Age     Dept   salary  promoted salary
# 0    Alice  30.0       HR  65000.0         650000.0
# 1      Bob  24.0       IT      NaN              NaN
# 2  Charlie  45.0  Finance  95000.0         950000.0
# 3    David   NaN       IT  75000.0         750000.0
# 4      Eve  29.0       HR  67000.0         670000.0
# 5    Alice  30.0       HR  65000.0         650000.0

# %%
#Data cleaning

#->1.Checking null values in the dataframe on all columns.
df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# salary             1
# promoted salary    1
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#       Name   Age     Dept   salary  promoted salary
# 0    Alice  30.0       HR  65000.0         650000.0
# 1      Bob  24.0       IT      NaN              NaN
# 2  Charlie  45.0  Finance  95000.0         950000.0
# 3    David  31.6       IT  75000.0         750000.0
# 4      Eve  29.0       HR  67000.0         670000.0
# 5    Alice  30.0       HR  65000.0         650000.0

# %%
df['Name']=df['Name'].replace('Charlie','Darsan')

# %%
df
# Out:
#      Name   Age     Dept   salary  promoted salary
# 0   Alice  30.0       HR  65000.0         650000.0
# 1     Bob  24.0       IT      NaN              NaN
# 2  Darsan  45.0  Finance  95000.0         950000.0
# 3   David  31.6       IT  75000.0         750000.0
# 4     Eve  29.0       HR  67000.0         670000.0
# 5   Alice  30.0       HR  65000.0         650000.0

# %%
#->2.Delaling with duplicate values...
df_dup = df[df.duplicated]
df_dup
# Out:
#     Name   Age Dept   salary  promoted salary
# 5  Alice  30.0   HR  65000.0         650000.0

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Name   Age     Dept   salary  promoted salary
# 0   Alice  30.0       HR  65000.0         650000.0
# 1     Bob  24.0       IT      NaN              NaN
# 2  Darsan  45.0  Finance  95000.0         950000.0
# 3   David  31.6       IT  75000.0         750000.0
# 4     Eve  29.0       HR  67000.0         670000.0

# %%
# invalid values:
# Lambda -> python
df["promoted salary"] = df["promoted salary"].apply(lambda x: x/10 if x > 650000 else x)
# Out:
# /tmp/ipython-input-3120380552.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["promoted salary"] = df["promoted salary"].apply(lambda x: x/10 if x > 650000 else x)

# %%
df
# Out:
#      Name   Age     Dept   salary  promoted salary
# 0   Alice  30.0       HR  65000.0         650000.0
# 1     Bob  24.0       IT      NaN              NaN
# 2  Darsan  45.0  Finance  95000.0          95000.0
# 3   David  31.6       IT  75000.0          75000.0
# 4     Eve  29.0       HR  67000.0          67000.0

# %%
#Joins and Merges
department_info ={
    "Dept":["HR","IT","Finance"],
    "Location":["New York","San Francisco", "Chicago"],
    "Manager":["Laura","Steve","Nina"]
}

# %%
df2 = pd.DataFrame(department_info)
df2
# Out:
#       Dept       Location Manager
# 0       HR       New York   Laura
# 1       IT  San Francisco   Steve
# 2  Finance        Chicago    Nina

# %%
#Concat
pd.concat([df,df2],axis=1)
# Out:
#      Name   Age     Dept   salary  promoted salary     Dept       Location  \
# 0   Alice  30.0       HR  65000.0         650000.0       HR       New York
# 1     Bob  24.0       IT      NaN              NaN       IT  San Francisco
# 2  Darsan  45.0  Finance  95000.0          95000.0  Finance        Chicago
# 3   David  31.6       IT  75000.0          75000.0      NaN            NaN
# 4     Eve  29.0       HR  67000.0          67000.0      NaN            NaN
#
#   Manager
# 0   Laura
# 1   Steve
# 2    Nina
# 3     NaN
# 4     NaN

# %%
#Merge
pd.merge(df,df2,on="Dept")
# Out:
#      Name   Age     Dept   salary  promoted salary       Location Manager
# 0   Alice  30.0       HR  65000.0         650000.0       New York   Laura
# 1     Bob  24.0       IT      NaN              NaN  San Francisco   Steve
# 2  Darsan  45.0  Finance  95000.0          95000.0        Chicago    Nina
# 3   David  31.6       IT  75000.0          75000.0  San Francisco   Steve
# 4     Eve  29.0       HR  67000.0          67000.0       New York   Laura

# %% [markdown]
# Importing File

# %%
data = pd.read_csv("/Exam_Score_Prediction.csv")

# %%
df1 = pd.DataFrame(data)

# %%
df1.head(10)
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
# 5           6   23    male   b.tech         3.48              65.4
# 6           7   17  female   b.tech         1.35              69.0
# 7           8   22    male     b.sc         5.48              51.1
# 8           9   18   other      bca         2.89              92.0
# 9          10   17    male      bba         6.77              44.8
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# ...

# %%
data.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB

# %%
df1[["study_hours","sleep_quality"]].head(10)
# Out:
#    study_hours sleep_quality
# 0         2.78          poor
# 1         3.37       average
# 2         7.88          poor
# 3         0.67       average
# 4         0.89          poor
# 5         3.48          good
# 6         1.35       average
# 7         5.48          poor
# 8         2.89          poor
# 9         6.77       average

# %%
df1.loc(20:30,["study_hours","sleep_quality"])
# Out:
#   File "/tmp/ipython-input-2446455998.py", line 1
#     df1.loc(20:30,["study_hours","sleep_quality"])
#               ^
# SyntaxError: invalid syntax

# %%
data.shape
# Out:
# (20000, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20000 non-null  int64
#  1   age               20000 non-null  int64
#  2   gender            20000 non-null  object
#  3   course            20000 non-null  object
#  4   study_hours       20000 non-null  float64
#  5   class_attendance  20000 non-null  float64
#  6   internet_access   20000 non-null  object
#  7   sleep_hours       20000 non-null  float64
#  8   sleep_quality     20000 non-null  object
#  9   study_method      20000 non-null  object
#  10  facility_rating   20000 non-null  object
#  11  exam_difficulty   20000 non-null  object
#  12  exam_score        20000 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 2.0+ MB
